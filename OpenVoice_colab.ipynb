# %% [markdown]
# <a href="https://colab.research.google.com/github/suleman-khawaja/Employee-Salary-Increment-Increment-Percentage-Calculator/blob/main/OpenVoice_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
